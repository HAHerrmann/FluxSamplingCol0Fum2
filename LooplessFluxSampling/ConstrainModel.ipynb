# %% [markdown]
# ### Imposing Model Constraints
#
# Here we take measured gas exchange, metabolite and proteomics data in order to constraint the flux of the reaction in the model by [Arnold and Nikoloski, 2014](https://www.ncbi.nlm.nih.gov/pubmed/24808102).
#
# We build four models using the experimental data:
# - Wild-type 20 degrees,
# - Wild-type after 7 days in 4 degrees,
# - fum2 mutant 20 degrees,
# - fum2 mutant after 7 days in 4 degrees.

# %%
# # Loading Required Packages 
# import cobra
# from cobra.flux_analysis import flux_variability_analysis
# from cobra.flux_analysis.loopless import add_loopless, loopless_solution
# from cobra.flux_analysis import pfba
# import pandas as pd
# import numpy as np
# import itertools

# %%
# Loading the protein data 
df = pd.read_excel(io="ProteinConc.xlsx")

# %%
# Loading the model 
# %run SetUpModel.ipynb
# Out:
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(ATCG00020 and ATCG00680 and ATCG00280 and ATCG00270 and ATCG00580 and ATCG00570 and ATCG00710 and ATCG00080 and ATCG00550 and ATCG00070 and ATCG00560 and ATCG00220 and ATCG00700 and (AT5G66570 or AT3G50820) and AT1G06680 and (AT4G21280 or AT4G05180) and AT1G79040 and AT1G44575 and ATCG00690 and AT3G21055 and AT2G30570 and AT2G06520 and AT1G67740 and ATCG00300)' for <Reaction PSII_h at 0x7f7033080c90>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(ATCG00540 and ATCG00720 and AT4G03280 and ATCG00730 and ATCG00600 and ATCG00590 and AT2G26500 and ATCG00210)' for <Reaction Cytb6f_h at 0x7f7032b44450>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '8*(ATCG00490) and 8*(AT5G38430 or AT5G38420 or AT1G67090 or AT5G38410)' for <Reaction RBC_h at 0x7f7033080e10>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '4*(AT3G26650 or AT1G12900) or (2*(AT3G26650 or AT1G12900) and 2*(AT1G42970))' for <Reaction GAPDH1_h at 0x7f7033080f50>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT3G55440 or AT2G21170)' for <Reaction TPI_h at 0x7f7033080f10>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '4*(AT2G01140 or AT4G26530 or AT3G52930 or AT4G38970 or AT5G03690 or AT2G21330)' for <Reaction FBPA_h at 0x7f7032eef590>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '4*(AT3G54050)' for <Reaction FBPase_h at 0x7f7032eefc50>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT3G60750 or AT2G45290)' for <Reaction FTK_h at 0x7f7032eef350>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '4*(AT2G01140 or AT4G26530 or AT3G52930 or AT4G38970 or AT5G03690 or AT2G21330)' for <Reaction SBPA_h at 0x7f7032eef450>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT3G55800)' for <Reaction SBPase_h at 0x7f7032eef050>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT3G60750 or AT2G45290)' for <Reaction STK_h at 0x7f7032eef490>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '8*(AT5G61410)' for <Reaction Ru5PE_h at 0x7f7032eef4d0>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT3G04790)' for <Reaction R5PI_h at 0x7f7032eef550>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT1G32060)' for <Reaction Ru5PK_h at 0x7f7032ecc410>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT4G24620)' for <Reaction PGI_h at 0x7f7032ecc8d0>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT5G19220 or AT1G27680 or AT4G39210 or AT2G21590) and 2*(AT5G48300 or AT1G05610)' for <Reaction AGPase_h at 0x7f7032eccc90>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT3G55440 or AT2G21170)' for <Reaction TPI_c at 0x7f7032f00c90>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '4*(AT4G26520 or AT4G26530 or AT3G52930 or AT2G36460 or AT5G03690)' for <Reaction FBPA_c at 0x7f7032f00d50>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '4*(AT1G43670)' for <Reaction FBPase_c at 0x7f7032f00d10>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '4*(AT1G07110)' for <Reaction F6PK2_c at 0x7f7032f00e90>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '4*(AT1G07110)' for <Reaction F26BPPh_c at 0x7f7032f00ed0>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT4G24620 or AT5G42740)' for <Reaction PGI_c at 0x7f7032f00bd0>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT5G20280) or 4*(AT5G20280)' for <Reaction S6PS_c at 0x7f7032f00fd0>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT2G35840 or AT3G52340)' for <Reaction S6PPh_c at 0x7f703308e4d0>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '4*(AT5G20830 or AT5G49190 or AT3G43190)' for <Reaction SucS_c at 0x7f703308e850>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '4*(AT1G53310 or AT2G42600 or AT3G14940 or AT1G68750)' for <Reaction PEPC2_c at 0x7f703308ec10>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT2G29560 or AT2G36530)' for <Reaction Enol_c at 0x7f703308ec50>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '4*(AT3G04120 or AT1G13440)' for <Reaction GAPDH2_c at 0x7f70330ab0d0>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '4*(AT1G79530 or AT1G16300)' for <Reaction GAPDH2_h at 0x7f70330abe90>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT1G74030 or AT2G36530)' for <Reaction Enol_h at 0x7f70330c4590>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '4*(AT3G04050 or AT5G08570 or AT3G25960 or AT2G36580 or AT3G55650 or AT3G55810 or AT5G63680 or AT3G52990)' for <Reaction PyrK_c at 0x7f70330c4550>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '4*(AT3G22960) and 4*(AT5G52920 or AT1G32440)' for <Reaction PyrK_h at 0x7f70330c4790>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT1G59900) and 2*(AT5G50850)' for <Reaction PyrDH1_m at 0x7f70330c4990>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT1G59900) and 2*(AT5G50850)' for <Reaction PyrDH2_m at 0x7f70330c4910>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '3*(AT3G52200 or AT3G13930 or AT1G54220)' for <Reaction DHLAcT_m at 0x7f70330c4c50>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT1G48030 or AT3G17240)' for <Reaction DHLDH2_m at 0x7f70330c4d50>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT5G65750 or AT3G55410)' for <Reaction KGDH_m at 0x7f70330c4750>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '3*(AT5G55070 or AT4G26910)' for <Reaction DHLST_m at 0x7f70330c4710>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '(ATMG01275 or ATMG01120 or ATMG00516) and (ATMG00285 or ATMG01320) and ATMG00990 and (ATMG00580 or ATMG00650) and (ATMG00513 or ATMG00665 or ATMG00060) and ATMG00270 and ATMG00510 and ATMG00070 and AT5G37510 and AT5G11770 (AT1G79010 or AT1G16700) and AT5G08530 and AT4G02580' for <Reaction cplx1_m at 0x7f7032f583d0>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '3*(ATMG01190) and 3*(AT5G08670 or AT5G08690 or AT5G08680) and AT2G33040 and (AT5G13450 or AT5G47030) and AT1G51650 and (ATMG00410 or ATMG01170) and 2*(ATMG00640 or ATMG00480) and 12*(ATMG01080 or AT2G07671) and AT3G52300' for <Reaction cplx5_m at 0x7f7032f58a10>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '8*(ATCG00490) and 8*(AT5G38430 or AT5G38420 or AT1G67090 or AT5G38410)' for <Reaction RBO_h at 0x7f7032f58b50>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '4*(AT1G20620 or AT1G20630 or AT4G35090)' for <Reaction CAT_p at 0x7f7032f58950>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT4G33010 or AT2G26080)' for <Reaction GlyDH_m at 0x7f7032f6b2d0>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT1G48030 or AT3G17240)' for <Reaction DHLDH1_m at 0x7f7032f6b1d0>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '4*(AT4G37930 or AT5G26780)' for <Reaction GlyHMT_m at 0x7f7032f7b190>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT2G13360)' for <Reaction SGAT_p at 0x7f7032f7b9d0>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '4*(AT2G19900 or AT5G11670 or AT5G25880)' for <Reaction MalDH2NADP_c at 0x7f7032f147d0>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '4*(AT5G11670 or AT5G25880 or AT1G79750)' for <Reaction MalDH2NADP_h at 0x7f7032f14990>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '4*(AT1G10670 or AT1G60810 or AT1G09430) and 4*(AT3G06650 orAT5G49460)' for <Reaction ATPCitL_c at 0x7f7032f26550>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '(AT5G16390 or AT5G15530) and AT5G35360 and 2*(AT2G38040) and 2*(ATCG00500)' for <Reaction ACoAC_h at 0x7f7032f26b90>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT4G35460 or AT2G17420 or AT2G41680)' for <Reaction TRXR_c at 0x7f7032f26f10>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT4G12440 or AT5G11160 or AT4G22570 or AT1G27450 or AT1G80050)' for <Reaction ADPRPPT_c at 0x7f7032f3b510>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT1G77760 or AT1G37130)' for <Reaction NO3R1_c at 0x7f7032f3ba90>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT1G77760 or AT1G37130)' for <Reaction NO3R2_c at 0x7f7032f3b8d0>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '4*(AT3G22890 or AT1G19920 or AT4G14680 or AT5G43780)' for <Reaction ATPSL_h at 0x7f7032f3bd90>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT3G54660)' for <Reaction GSSGR_h at 0x7f7032f3bf50>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '(AT1G08065 or AT5G04180 or AT4G20990 or AT4G21000 or AT2G28210 or AT3G52720) or 8*(AT1G23730 or AT5G14740)' for <Reaction HCO3DHA_c at 0x7f7032f3bc10>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '(AT4G20990 or AT1G08080 or AT3G52720) or 8*(AT1G23730 or AT1G70410 or AT1G58180 or AT3G01500 or AT5G14740 or AT4G33580)' for <Reaction HCO3DHA_h at 0x7f7032f3ba50>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '6*(AT3G57560)' for <Reaction AGluK at 0x7f70328120d0>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT5G08100) and 2*(AT3G16150)' for <Reaction Asnase_c at 0x7f703282b0d0>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '6*(AT1G55920 or AT2G17640 or AT3G13110 or AT4G35640 or AT5G56760)' for <Reaction SerAcT_c at 0x7f703282b310>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '6*(AT1G55920 or AT3G13110)' for <Reaction SerAcT_h at 0x7f7032812110>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '6*(AT1G55920 or AT3G13110)' for <Reaction SerAcT_m at 0x7f703282b710>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT4G14880 or AT3G22460)' for <Reaction CysS_c at 0x7f703282b890>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT3G61440 or AT3G03630 or AT4G14880 or AT2G43750)' for <Reaction CysS_h at 0x7f703282b9d0>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT3G61440 or AT3G03630 or AT2G43750 or AT5G28020)' for <Reaction CysS_m at 0x7f7032812e90>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '6*(AT5G18170 or AT5G07440 or AT3G03910)' for <Reaction GluDH1NAD_m at 0x7f703282b590>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '6*(AT5G18170 or AT5G07440 or AT3G03910)' for <Reaction GluDH1NADP_m at 0x7f703282bed0>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '6*(AT5G18170 or AT5G07440)' for <Reaction GluDH2NAD_m at 0x7f703282bf10>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '6*(AT5G17330 or AT1G65960 or AT2G02000 or AT2G02010 or AT3G17760)' for <Reaction GluDC_c at 0x7f703282bf50>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT3G22200)' for <Reaction GABATA1_m at 0x7f703282ba90>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT3G22200)' for <Reaction GABATA2_m at 0x7f703283f590>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '4*(AT1G79440)' for <Reaction SCASeADH_m at 0x7f703283f390>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '8*(AT5G37600 or AT3G17820 or AT5G16570 or AT1G66200)' for <Reaction GlnS_c at 0x7f703283f550>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '8*(AT3G17820 or AT1G48470 or AT5G35630)' for <Reaction GlnS_h at 0x7f703283f7d0>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '8*(AT5G35630)' for <Reaction GlnS_m at 0x7f703283f950>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '4*(AT1G20620 or AT1G20630 or AT4G35090)' for <Reaction CAT_h at 0x7f703283f190>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT2G13360' for <Reaction SGAT_h at 0x7f703283f510>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '4*(AT3G10050)' for <Reaction ThrDA_h at 0x7f70327d5750>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT3G48560)' for <Reaction ALS1_h at 0x7f70327d5810>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT3G48560)' for <Reaction ALS2_h at 0x7f70327d59d0>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT3G48560)' for <Reaction ALS3_h at 0x7f70327d5c10>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT1G18500) or 4*(AT1G74040)' for <Reaction 2IPMS_h at 0x7f70327d5e90>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '4*(AT4G19710 or AT1G31230 or AT5G13280 or AT3G02020 or AT5G14060)' for <Reaction AspK_h at 0x7f70327e7110>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT1G14810)' for <Reaction Asp_DASH_SeADH_h at 0x7f70327e72d0>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT4G33680)' for <Reaction DAPAT_h at 0x7f70327e7750>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '4*(AT1G31230 AT4G19710)' for <Reaction HSerDHNADP_h at 0x7f70327e7cd0>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '4*(AT1G31230 AT4G19710)' for <Reaction HSerDHNAD_h at 0x7f70327e7890>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '4*(AT3G57050)' for <Reaction CTHL_h at 0x7f70327fd150>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT2G44160 or AT3G59970)' for <Reaction 5M_DASH_THFor_c at 0x7f70327fd090>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '4*(AT4G13930 or AT4G13890 or AT1G22020 or AT1G36370 or AT4G37930 or AT5G26780)' for <Reaction GlyHMT_c at 0x7f70327fd590>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT4G29840 or AT1G72810)' for <Reaction ThrS_h at 0x7f703278ef50>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT1G24807) and 2*(AT3G55870 or AT5G05730 or AT2G29690)' for <Reaction ANTS_h at 0x7f703278eed0>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT2G38280)' for <Reaction AMPDA_c at 0x7f70327a3fd0>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT3G57610)' for <Reaction DCAMPS_h at 0x7f70327b81d0>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT2G21790) and 2*(AT3G23580 or AT3G27060)' for <Reaction ADPR_c at 0x7f70327b8cd0>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT2G21790) and 2*(AT3G23580 or AT3G27060)' for <Reaction CDPR_c at 0x7f70327b8f10>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT2G21790) and 2*(AT3G23580 or AT3G27060)' for <Reaction GDPR_c at 0x7f70327b8f50>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '2*(AT2G21790) and 2*(AT3G23580 or AT3G27060)' for <Reaction UDPR_c at 0x7f70327b8e10>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '3*(AT3G46940)' for <Reaction dUTPP_c at 0x7f703274d550>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '6*(AT4G09320 or AT5G63310)' for <Reaction GDPK_c at 0x7f703274d190>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '6*(AT4G09320 or AT5G63310)' for <Reaction GDPK_h at 0x7f703274d510>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '6*(AT4G09320 or AT5G63310)' for <Reaction UDPK_c at 0x7f703274da90>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '6*(AT4G09320 or AT5G63310)' for <Reaction dADPK_c at 0x7f703274dbd0>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '6*(AT4G09320 or AT5G63310)' for <Reaction dCDPK_c at 0x7f703274dd10>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '6*(AT4G09320 or AT5G63310)' for <Reaction dGDPK_c at 0x7f703274de50>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '6*(AT4G09320 or AT5G63310)' for <Reaction dTDPK_c at 0x7f703274df90>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '6*(AT4G09320 or AT5G63310)' for <Reaction dUDPK_c at 0x7f703274df50>
# Mal_c --> Fum_c + H2O_c
# (0.0, 1000.0)
# Directionality changed. Dyson et al. 2016
#
# Mal_c -->
# Fum_c -->
# starch1_h -->
# G6P_c + Pi_h --> G6P_h + Pi_c
# G6P_c + Pi_h <=> G6P_h + Pi_c
# (-1000.0, 1000.0)
# Set to be bidirectional. Dyson et al. 2015
#
# PGA_h + Pi_c <=> PGA_c + Pi_h
# (0.01, 1000.0)
# Set as one directional to avoid futile cycles
# GAP_h + Pi_c <=> GAP_c + Pi_h
# (0.01, 1000.0)
# Set as one directional to avoid futile cycles

# %%
# Functions for running the models 

def ATPNADPH(atp,nadph):
    '''Setting the ATP and NADPH flux. Lower bound plus one'''
    NADPH = model.reactions.get_by_id('Fd_DASH_NADPR_h')
    ATPase = model.reactions.get_by_id('ATPase_h')
    lohi = 1.0
    NADPH.lower_bound = nadph - lohi
    NADPH.upper_bound = nadph + lohi
    ATPase.lower_bound = atp- lohi
    ATPase.upper_bound = atp + lohi
    print(NADPH)
    print(NADPH.bounds)
    print(ATPase)
    print(ATPase.bounds)
    print(" ")
    
def setobjective(FunName,obj="Maximum"):
    '''Setting the objective function of the model to FunName'''
    model.objective = model.reactions.get_by_id(FunName)
    model.objective_direction = obj
    print(model.objective)
    print("Set as objective function. \n")
    
def constr(reacs,Dat1,Dat2,Dat3,Dat4):
    '''Constraints model reactions for a specific genotype and temperature'''
    for r in reacs:
        upper_vals = []
        lower_vals = []
        for g in r.genes:
            # Get index of protein in data file 
            ind = all_atg.index(g.id)
            # Scaling the values for setting fluxes 
            vals = [i/4000. for i in Dat1[ind],Dat2[ind],Dat3[ind],Dat4[ind]]
            val = np.mean(vals)
            sterr = np.std(vals)/np.sqrt(len(vals))
            upper = val + sterr
            lower = val - sterr
            upper_vals.append(upper)
            lower_vals.append(lower)
        # Constraint flux of forward reaction
        r.upper_bound = round(sum(upper_vals),3)
        # Constraint flux of lower reaction 
        if r.lower_bound < 0.0:
            r.lower_bound = round(-sum(upper_vals),3)
        # No lower bound b/c don't know localization or enzymes are used to in other reactions 

def TPTratio(TPT1,TPT2):
    '''To set TPT1 to TPT2 flux ratios'''
    r = model.reactions.get_by_id('Tr_TPT2')
    r.lower_bound = 0.0
    r.upper_bound = TPT2
    r = model.reactions.get_by_id('Tr_TPT1')
    r.lower_bound = 0.0
    r.upper_bound = TPT1
    #print(cobra.flux_analysis.flux_variability_analysis(model, [NADPH,ATPase]))
    print(" ")
    #inds = (1,101,202,302,401,501,601,701,801,901)
    
def subsys(subsystem):
    for r in model.reactions:
        if r.subsystem == subsystem:
            print(r.reaction)

# %%
# # Setting the ATP and NADPH production fluxes 
# setobjective("FumHA_c")
# ATPNADPH(107.0,160.0) #0.668
# #ATPNADPH(97.0,220.0) #0.441
# flux_variability_analysis(model,["Tr_TPT1","Tr_TPT2"])
# #subsys("light reactions")

# %%
# Get list of all possible proteins in the model
gene_ids = []
for g in model.genes:
    gene_ids.append(g.id)
# Get list of all measured proteins 
all_atg = []
x=df["Accession"]
for atg in x.values:
    all_atg.append(atg)
# Comparing the measured protein concentrations to those which are in the model 
model_atg = [] # Total measured proteins in model
model_atg_final = [] # Proteins with direct reaction constraint (i.e. single responsible protein)
model_rxns_atg = [] # Model reactions with direct constraints (i.e. single responsible protein)
model_rxns_atgs = [] # Model reactions with multiple possible constraints 
model_atgs_final = [] # Proteins with multiple possible constraints 

for atg in x.values: # Check if protein is in the model 
    if atg in gene_ids:
        model_atg.append(atg)
        # Only parameterize that reaction if that enzyme is the only one responsible for that reaction
        for r in model.genes.get_by_id(atg).reactions:
            if len(r.genes) == 1:
                model_rxns_atg.append(r)
                model_atg_final.append(atg)
            else:
                prot_names = []
                for g in r.genes:
                    prot_names.append(g.id)
                if set(prot_names).issubset(set(all_atg)):
                    model_rxns_atgs.append(r)
                    model_atgs_final = model_atgs_final + prot_names
# Feasible constraint summary 
print("Total measured proteins: {}".format(len(all_atg)))  
print("Total measured proteins in model: {}".format(len(model_atg))) 
print("Total model reactions: {}".format(len(model.reactions)))
print(" ")
# Reactions with simple constraints 
print("Total model reactions with single constraints: {}".format(len(set(model_rxns_atg))))
print("Model proteins for single constraints: {}".format(len(set(model_atg_final))))
print(" ")
# Reactions with multiple possible constraints 
print("Total model reactions with multiple constraints: {}".format(len(set(model_rxns_atgs))))
print("Total model proteins for possible constraints: {}".format(len(set(model_atgs_final))))
# Total constained reactions
constr_reacs = set(model_rxns_atg + model_rxns_atgs) #these are the reactions constrained in the models 
constr_ids = []
for r in constr_reacs:
    constr_ids.append(r.id)
# Out:
# Total measured proteins: 2427
# Total measured proteins in model: 245
# Total model reactions: 552
#
# Total model reactions with single constraints: 62
# Model proteins for single constraints: 49
#
# Total model reactions with multiple constraints: 39
# Total model proteins for possible constraints: 53

# %%
# Setting up the Model Constraints
# for different genotypes and temperatures 

def all_constr(C,M,F,S,Cond):
    # Metabolite Constraints 
    print("\n--------- {} -----------\n".format(Cond))
    f1=0.99*200
    f2=1.01*200
    rMal = model.reactions.get_by_id('Mal_Store')
    rFum = model.reactions.get_by_id('Fum_Store')
    rStarch = model.reactions.get_by_id('Starch_Store')
    rCO2 = model.reactions.get_by_id('Im_CO2')
    FumHA_c = model.reactions.get_by_id('FumHA_c')
    rResp = model.reactions.get_by_id('Tr_Pyr2')
    rCO2.upper_bound = C+1.0
    rCO2.lower_bound = C-1.0
    rResp.lower_bound = rCO2.lower_bound*0.15/3
    rResp.upper_bound = 1000.0
    rMal.upper_bound = (M+0.001)*f2
    rMal.lower_bound = (M-0.001)*f1
    rFum.upper_bound = (F+0.001)*f2
    rFum.lower_bound = (F-0.001)*f1
    rStarch.upper_bound = (S-0.001)*f2
    rStarch.lower_bound = (S-0.001)*f1
    # Proteomic Constraints 
    name1 = "{} 1".format(Cond)
    name2 = "{} 2".format(Cond)
    name3 = "{} 3".format(Cond)
    name4 = "{} 4".format(Cond)
    constr(constr_reacs,df[name1],df[name2],df[name3],df[name4])
    # Mutant Knockout
    if "fum2" in Cond:
        r = model.reactions.get_by_id('FumHA_c')
        r.upper_bound = 0.0 # Mutant knockout 
        r.lower_bound = 0.0 
    # Loopless Constraints 
    print("For Loopless...")
    setobjective("Mal_Store",obj="Minimum")
    loopless = loopless_solution(model)
    print(loopless["Tr_TPT1"])
    print(loopless["Tr_TPT2"])
    print(" ")
    for r in model.reactions:
        if (loopless[r.id] == 0.0):
            r.lower_bound = 0.0
            r.upper_bound = 0.0
        else:
            pass 
    FVA = flux_variability_analysis(model,['Fd_DASH_NADPR_h'])
    modelname = "Arnold2014_{}_Loopless.xml".format(Cond)
    cobra.io.write_sbml_model(model,modelname,use_fbc_package=False)
    print("MODEL SAVED. Go do flux sampling in MATLAB. \n")
    # Resetting the mutant knockout 
    if "fum2" in Cond:
        r = model.reactions.get_by_id('FumHA_c')
        r.upper_bound = 1000.0 
        r.lower_bound = 0.0

# %%
# Parameterizing the model for Genotype and Condition
# all_constr(100,0.003,0.006,0.028,"WT Cntl")
# all_constr(100,0.012,0.0,0.042,"fum2 Cntl")
# all_constr(100,0.012,0.023,0.051,"WT cold")
# all_constr(94,0.025,0.0,0.063,"fum2 Cold")
# Out:
# --------- fum2 Cold -----------
#
# For Loopless...
# Minimize
# -1.0*Mal_Store_reverse_8006f + 1.0*Mal_Store
# Set as objective function.
#
# 0.01
# 39.45111111111003
#
# MODEL SAVED. Go do flux sampling in MATLAB.

# %%
# CHRR flux sampling (MATLAB SCRIPT)
# Plotting the overlapping sampling distribution (NEW PYTHON SCRIPT)
